# %%
import numpy as np
import pandas as pd
import re
import requests
import bs4
import time

# %%
file = '/tempo/merged_clean.csv'

#convert df into a numpy array
df = pd.read_csv(file)

# convert the relationships into categories
rel_cat = df['Relation'].astype('category')

# label each unique value in the column 'Relation' with a number
labels = rel_cat.cat.codes.to_numpy()

# get the conversion dictionary between the labels and the numbers
conversion_dict = np.array(list(enumerate(rel_cat.cat.categories)))

# %%
# extract all unique words (both word A and word B) that are 3 or 4 letters long
acronyms = np.concatenate((df['Word A'], df['Word B']))
acronyms = np.unique(acronyms)
# filter by length
acronyms = acronyms[np.where(np.array([len(acronym) < 5 for acronym in acronyms]) == True)]
print(acronyms)
# Out:
# ['aadl' 'aam' 'ab' 'abc' 'abm' 'abv' 'ac' 'acf' 'acl' 'acl2' 'aco' 'ada'
#  'adam' 'add' 'ade' 'adls' 'adp' 'adts' 'aer' 'aes' 'afs' 'agda' 'agg'
#  'ahp' 'ai' 'al' 'alc' 'alp' 'amcs' 'ann' 'anns' 'ant' 'aop' 'api' 'apis'
#  'ar' 'arc' 'asa' 'asic' 'asl' 'asm' 'asp' 'asr' 'at' 'atl' 'atpg' 'au'
#  'auc' 'auv' 'bbc' 'bbo' 'bcg' 'bci' 'bcis' 'bdd' 'bdds' 'beam' 'beta'
#  'bfo' 'bim' 'blas' 'bleu' 'blob' 'blog' 'blur' 'bmc' 'bmi' 'bn' 'bnc'
#  'bnf' 'bnns' 'bns' 'bot' 'bp' 'bpa' 'bpm' 'bpmn' 'bpn' 'bpnn' 'bpp'
#  'bpso' 'bptt' 'bug' 'bus' 'ca' 'cad' 'cam' 'cart' 'casl' 'cba' 'cbir'
#  'cbr' 'cca' 'ccg' 'cd' 'ce' 'cer' 'cf' 'cfg' 'cfgs' 'cgal' 'cgp' 'cgs'
#  'chat' 'chc' 'chin' 'chr' 'chrs' 'ci' 'ciao' 'cit' 'clip' 'clir' 'clp'
#  'cmac' 'cmc' 'cnn' 'cnns' 'cob' 'code' 'cog' 'coil' 'coq' 'core' 'cp'
#  'cpg' 'cpgs' 'cps' 'cpu' 'cqa' 'cql' 'cqp' 'cr' 'crf' 'crfs' 'crm' 'crt'
#  'csa' 'cscl' 'cseq' 'csp' 'csps' 'csr' 'ct' 'cta' 'ctc' 'ctl' 'cuda'
#  'cure' 'cut' 'cv' 'cvc3' 'da' 'dag' 'dbms' 'dbn' 'dbns' 'dca' 'dcc' 'dcd'
#  'dcg' 'dcm' 'dct' 'ddc' 'de' 'dea' 'ded' 'df' 'dga' 'dibr' 'digg' 'diva'
#  'dl' 'dlp' 'dlr' 'dlv' 'dm' 'dmps' 'dmus' 'dnn' 'dnns' 'dob' 'dom' 'dop'
#  'dp' 'dpa' 'dpm' 'dpp' 'dr' 'dram' 'drs' 'drt' 'ds' 'dsl' 'dsp' 'dsps'
#  'dt' 'dtc' 'dtd' 'dtds' 'dti' 'dtsp' 'dtw' 'dw' 'dwt' 'e' 'ea' 'easy'
#  'ebl' 'ebmt' 'ebse' 'ecc' 'ecg' 'ecoc' 'eda' 'edas' 'edf' 'edge' 'eeg'
#  'eer' 'ehrs' 'ehw' 'eid' 'ekf' 'el' 'elm' 'em' 'emd' 'emf' 'emg' 'eog'
#  'ep' 'epic' 'eps' 'erp' 'esa' 'esn' 'esns' 'eth' 'euf' 'f' 'f0' 'f1' 'f2'
#  'facs' 'fact' 'far' 'fc' 'fca' 'fcbf' 'fcm' 'fcms' 'fcns' 'fdr' 'fds'
#  'ff' 'ffbp' 'fft' 'fis' 'fjsp' 'flc' 'flcs' 'flow' 'flux' 'fm' 'fmri'
#  'fnn' 'font' 'fpga' 'fr' 'frp' 'frr' 'fsms' 'fuml' 'ga' 'gait' 'gar'
#  'gaze' 'gc' 'gcc' 'gdbs' 'gdm' 'ge' 'gene' 'gep' 'get' 'gf' 'ggp' 'ghc'
#  'gi' 'gist' 'git' 'giza' 'glcm' 'gmf' 'gmm' 'gmms' 'gmr' 'go' 'gp' 'gps'
#  'gpu' 'gpus' 'gra' 'grid' 'grnn' 'grns' 'gsa' 'gsp' 'gui' 'gyro' 'h'
#  'h2pc' 'hash' 'haze' 'hci' 'hdfs' 'hdl' 'hdp' 'hga' 'hint' 'hip' 'hive'
#  'hl' 'hl7' 'hmd' 'hmm' 'hmms' 'hog' 'host' 'hpsg' 'hri' 'hsp' 'html'
#  'hub' 'hvs' 'hyb' 'ibea' 'ic' 'ica' 'icon' 'icp' 'ict' 'id' 'id3' 'ida'
#  'ide' 'idf' 'idle' 'ie' 'ifc' 'ig' 'iga' 'ilc' 'ilp' 'imf' 'imu' 'ip'
#  'ipca' 'iris' 'irt' 'is a' 'it' 'j48' 'java' 'jess' 'jml' 'join' 'jpeg'
#  'jssp' 'jvm' 'kb' 'kdd' 'kelm' 'key' 'kf' 'km' 'knn' 'kpca' 'kqml' 'kr'
#  'l1' 'l3' 'law' 'lbp' 'lcd' 'lcs' 'lcss' 'lda' 'lds' 'ldss' 'led' 'lem'
#  'lens' 'lex' 'lf' 'lfda' 'lfg' 'lgp' 'lh' 'lift' 'linq' 'liwc' 'lle'
#  'llvm' 'lm' 'lmi' 'lmis' 'lock' 'lof' 'log' 'loop' 'lp' 'lpc' 'lpp' 'lqr'
#  'lr' 'lsa' 'lsb' 'lsh' 'lsi' 'lstm' 'ltag' 'ltl' 'ltm' 'lts' 'lung' 'lvq'
#  'mape' 'mask' 'max' 'mbt' 'mc' 'mcar' 'mcda' 'md5' 'mda' 'mdd' 'mde'
#  'mdl' 'mdp' 'mdps' 'me' 'mebn' 'menu' 'mep' 'mesh' 'mfcc' 'mhi' 'mkl'
#  'mlc' 'mle' 'mlp' 'mlps' 'mmas' 'mmhc' 'mole' 'mop' 'mp' 'mpc' 'mpe'
#  'mpeg' 'mpi' 'mr' 'mra' 'mrdm' 'mrf' 'mrfs' 'mri' 'mrmr' 'msa' 'msc'
#  'mse' 'msi' 'mso' 'mt' 'mtf' 'mtl' 'mvp' 'mwe' 'mwes' 'n' 'na' 'nand'
#  'nb' 'nbc' 'nc' 'ne' 'neon' 'ner' 'nfr' 'nirs' 'nl' 'nlg' 'nlp' 'nltk'
#  'nmf' 'nmfs' 'nmpc' 'nmt' 'nn' 'nns' 'norm' 'noun' 'ns 2' 'oaa' 'obda'
#  'obo' 'ocl' 'ocr' 'ofmc' 'olap' 'oled' 'omg' 'oner' 'oop' 'opc' 'oql'
#  'orb' 'orl' 'orm' 'osa' 'osns' 'owl' 'p' 'p300' 'page' 'palm' 'par' 'pat'
#  'path' 'pbil' 'pbl' 'pbr' 'pc' 'pca' 'pcfg' 'pcnn' 'pd' 'pdc' 'pddl'
#  'pdf' 'pdm' 'peg' 'pen' 'pepa' 'perl' 'pesc' 'pet' 'pgl' 'phad' 'pi'
#  'pid' 'pin' 'plcs' 'pls' 'plsa' 'pmi' 'pmp' 'pnn' 'pns' 'por' 'port'
#  'pose' 'ppdb' 'ppdg' 'ppg' 'pram' 'prf' 'pris' 'prm' 'prom' 'ps' 'psms'
#  'psnr' 'pso' 'puf' 'pufs' 'pvs' 'qa' 'qap' 'qbf' 'qbfs' 'qe' 'qep' 'qeps'
#  'qnns' 'qr' 'qsar' 'r' 'ram' 'rank' 'rbac' 'rbc' 'rbf' 'rbfn' 'rbm'
#  'rbms' 'rbmt' 'rbr' 'rc5' 'rdf' 'rdfa' 'rdfs' 'rf' 'rfe' 'rfid' 'rgb'
#  'rib' 'ring' 'rmn' 'rmse' 'rnn' 'rnns' 'roc' 'roi' 'roni' 'ror' 'row'
#  'rpf' 'rpn' 'rrts' 'rsa' 'rsc' 'rsms' 'rst' 'rsvp' 'rtec' 'rtos' 'rts'
#  'rup' 'rvm' 's1' 's2' 'sal' 'sale' 'sapa' 'sat' 'sbe' 'sbvr' 'sc' 'scan'
#  'scar' 'scj' 'scm' 'sd' 'sdf' 'sdre' 'sdsi' 'se' 'seam' 'semg' 'sems'
#  'seus' 'sfs' 'sgd' 'shif' 'si' 'sift' 'skew' 'skos' 'slam' 'slip' 'slrs'
#  'slt' 'slu' 'smd' 'smo' 'smt' 'smv' 'sn' 'snn' 'snns' 'so' 'soap' 'soar'
#  'soc' 'som' 'soma' 'sov' 'spam' 'spea' 'spec' 'spin' 'spl' 'spls' 'spmv'
#  'spn' 'spns' 'spso' 'spss' 'sql' 'sr' 'src' 'srn' 'ssa' 'ssc' 'sse' 'ssl'
#  'st' 'sta' 'stan' 'star' 'stc' 'std' 'stdp' 'stlf' 'stm' 'surf' 'svc'
#  'svd' 'svdd' 'svm' 'svms' 'svr' 'svs' 'swrl' 'tag' 'tan' 'tc' 'tcl'
#  'tctl' 'td' 'tdnn' 'tea' 'tfs' 'tgds' 'tggs' 'thai' 'tla' 'tlp' 'tm'
#  'tmis' 'toy' 'tpm' 'tree' 'trie' 'trot' 'trp' 'tso' 'tsp' 'tsps' 'tsvm'
#  'ttp' 'typo' 'uav' 'uavs' 'ubm' 'ucs' 'uct' 'udfs' 'ufo' 'ui' 'uml'
#  'umls' 'urdu' 'uri' 'url' 'utp' 'vc' 'vcc' 'vcdb' 'vcg' 'vdm' 'verb'
#  'vhdl' 'vlsi' 'vmd' 'vns' 'vo' 'vop' 'vq' 'vqa' 'vrml' 'vsm' 'w3c' 'wam'
#  'weka' 'wer' 'wfst' 'wiki' 'wine' 'wnn' 'word' 'worm' 'wsat' 'wsd' 'wsdl'
#  'wsds' 'wsi' 'wsml' 'wt' 'www' 'xc' 'xfds' 'xmi' 'xml' 'xor' 'xrml'
#  'xsds' 'xsg' 'xtea' 'yacc' 'yago' 'yale' 'yiq' 'z3']

# %%
def regex_finder(acronym, sent):
    """
    Check the sentences using regex
    """
    if acronym[-1] == 's':
        definition = regex_finder(acronym[:-1], sent)
        if definition:
            return definition

    # split the sentence into words by spaces and hyphens
    words = re.split(r'[-\s]', sent)
    original_words = words.copy()
    prepositions = ["at", "on", "by", "in", "by", "to", "of"]

    # delete prepositions and words without a single letter
    words = [word for word in words if re.search(r'[a-zA-Z]', word) and word not in prepositions]
    
    position = None

    # get the word position of the acronym in the sentence, using regex. It can be case insensitive. The acronym can be in brackets
    for i in range(len(words)):
        if re.search(rf"\b{acronym.upper()}\b", words[i]):
            position = i
    # get the number of letters in the acronym, excluding special characters
    if position is not None:
        length = len(acronym)
        # disregard if it would cause an index out of bounds error
        if position - length >= 0:
            words_before = words[position - length:position]
            # remove special characters frpm each word
            words_before = [re.sub(r"[^a-zA-Z]", "", word) for word in words_before]
        else:
            words_before = None
        if position + length < len(words):
            words_after = words[position + 1:position + 1 + length]
            words_after = [re.sub(r"[^a-zA-Z]", "", word) for word in words_after]
        else:
            words_after = None
        
        # print(words_before)
        # check if the words_before and words_after start with the same letters
        try:
            if words_before:
                for i in range(length):
                    if words_before[i][0].lower() != acronym[i]:
                        break
                else:
                    return " ".join(words_before)
        
            if words_after:
                for i in range(length):
                    if words_after[i][0].lower() != acronym[i]:
                        break
                else:
                    return " ".join(words_after)
        except:
                raise Exception(f"{words_after=} {acronym=} {length=} {position=} {sent=}")
        return None

def API_finder(acronym):
    """
    This function takes a string and returns the definition of the acronym.
    """
    time.sleep(5)
    url = f"https://www.acronymfinder.com/Information-Technology/{acronym}.html"
    response = requests.get(url)
    # find the class "result-list__body__meaning"
    soup = bs4.BeautifulSoup(response.text, 'html.parser')
    meaning = soup.find(class_="result-list__body__meaning")
    if meaning is None:
        return None

    # delete everything after the bracket
    definition = re.sub(r"\(.*\)", "", meaning.text)
    length = len(acronym)
    # only keep the first {length} words of the definition
    definition = definition.split()[:length]

    return " ".join(definition)

def get_acronym_defintion(acronym):
    # get all the indexes where acronym is either word A or word B
    indexes = df[(df['Word A'] == acronym) | (df['Word B'] == acronym)].index

    for i in indexes:
        definition = regex_finder(acronym, df['Sentence'][i])
        if definition:
            return definition
    # definition = API_finder(acronym)
    # if definition:
    #     return definition
    return None

sent = "We investigate the fading cognitive multiple access wiretap channel (CMAC-WT), in which two secondary-user transmitters (STs) send secure messages to a secondary-user receiver (SR) in the presence of an eavesdropper (ED) and subject to interference threshold constraints at multiple primary-user receivers (PRs)."
word = "wt"
print(regex_finder(word, sent))
# Out:
# which two

# %%
acronym = 'wt'
for i in range(len(df)):
    if  (df['Word A'][i] == acronym) | (df['Word B'][i] == acronym):
        print(df['Word A'][i], ' ', df['Word B'][i])
        print(df['Sentence'][i])
# Out:
# st   wt
# We investigate the fading cognitive multiple access wiretap channel (CMAC-WT), in which two secondary-user transmitters (STs) send secure messages to a secondary-user receiver (SR) in the presence of an eavesdropper (ED) and subject to interference threshold constraints at multiple primary-user receivers (PRs).
# st   wt
# The validity of the ladder approximation (LA) in QCD and QED in the context of the corresponding Schwinger-Dyson (SD) equations and Slavnov-Taylor (ST) and Ward-Takahashi (WT) identities is investigated.
# artificial neural network   wt
# An artificial neural network (ANN) is used to obtain an optimal coordination signal to improve frequency response. As a proof of concept, the proposed coordination is tested on a 9-bus test system that includes a wind farm with 5 WTs.
# ann   wt
# An artificial neural network (ANN) is used to obtain an optimal coordination signal to improve frequency response. As a proof of concept, the proposed coordination is tested on a 9-bus test system that includes a wind farm with 5 WTs.

# %%
definitions = dict()
for acronym in acronyms:
    definition = get_acronym_defintion(acronym)
    if definition:
        print(f"{acronym} : {definition}")
        definitions[acronym] = definition

# acronym = "elm"
# definition = get_acronym_defintion(acronym)
# print(f"{acronym} -> {definition}")
# Out:
# aadl : Architecture Analysis Design Language
# aam : active appearance model
# ab : Aharonov Bohm
# abc : artificial bee colony
# aco : Ant Colony Optimization
# add : Algebraic Decision Diagrams
# adls : Activities Daily Living
# adp : adaptive dynamic programming
# adts : abstract data type
# aer : Automatic emotion recognition
# aes : advanced encryption standard
# afs : Andrew File System
# agg : abstract ground graph
# ahp : Analytic Hierarchy Process
# ai : artificial intelligence
# alp : Abductive Logic Programming
# amcs : Adaptive Mixed Criticality
# ann : Artificial Neural Network
# anns : Artificial Neural Network
# aop : Aspect Oriented Programming
# api : Application Program Interface
# apis : Application Programming Interface
# ar : Augmented Reality
# arc : Astrophysical Research Consortium
# asa : Adaptive simulated annealing
# asic : application specific integrated circuit
# asm : Active Shape Models
# asp : answer set programming
# asr : automatic speech recognition
# atl : adaptive triplet loss
# au : Action Unit
# auc : area under curve
# bci : Brain Computer Interfaces
# bcis : Brain Computer Interface
# bdds : Binary Decision Diagrams
# bfo : Basic Formal Ontology
# bim : Building Information Modelling
# blas : Basic Linear Algebra Subroutine
# bmc : Bounded Model Checking
# bmi : brain machine interface
# bn : Bayesian Network
# bnc : British National Corpus
# bns : Bayesian Network
# bp : back propagation
# bpa : basic probability assignment
# bpm : Business process management
# bpmn : Business Process Modeling Notation
# bpnn : Blaschke Product Neural Network
# bpso : Binary Particle Swarm Optimization
# bptt : Back propagation through time
# ca : complementation algebra
# cad : computer aided design
# cam : Content Addressable Memory
# cart : classification and regression trees
# casl : Common Algebraic Specification Language
# cba : Classification Based Association
# cbir : Content based image retrieval
# cbr : Case Based Reasoning
# cca : canonical correlation analysis
# ccg : Combinatory Categorial Grammar
# cd : common denominator
# ce : carrier emitter
# cer : Character Error Rate
# cf : collaborative filtering
# cfg : control flow graph
# cfgs : context free grammar
# cgal : Computational Geometry Algorithms Library
# cgp : Cartesian Genetic Programming
# cgs : Conceptual Graphs
# chr : Constraint Handling Rules
# chrs : Constraint Handling Rules
# ci : code intelligence
# clir : Cross Language Information Retrieval
# clp : constraint logic programming
# cmac : Cerebellar Model Articulation Controller
# cmc : Computer Mediated Communication
# cnn : convolutional neural networks
# cnns : convolutional neural network
# cob : Convolutional Oriented Boundaries
# cp : Constraint Programming
# cpg : central pattern generator
# cpgs : contextual parameter generator
# cps : cyber physical systems
# cpu : central processing unit
# cqa : conversational question answering
# crf : Conditional Random Fields
# crfs : Conditional Random Field
# crm : customer relationship management
# cscl : Computer Supported Collaborative Learning
# csp : Common spatial pattern
# csr : compressed sparse row
# ct : computed tomography
# cta : channel training authentication
# ctc : connectionist temporal classification
# ctl : Computation Tree Logic
# cuda : Compute Unified Device Architecture
# da : domain adaptation
# dag : directed acyclic graph
# dbn : Deep Belief Network
# dbns : Deep Belief Network
# dca : deterministic cellular automaton
# dcc : dependency core calculus
# dcg : Definite Clause Grammars
# dcm : Dynamic Causal Modelling
# dct : discrete cosine transform
# de : differential evolution
# dea : data envelopment analysis
# dga : distributed genetic algorithm
# dibr : depth image based rendering
# dl : Description Logic
# dlp : Disjunctive Logic Programming
# dm : Data Mining
# dmus : decision making unit
# dnn : deep neural network
# dnns : deep neural network
# dom : Document Object Model
# dop : Data Oriented Parsing
# dp : dynamic programming
# dpp : dynamic programming principle
# dr : diabetic retinopathy
# dram : dynamic random access memory
# drs : Discourse Representation Structure
# drt : discourse representation theory
# ds : Discovery Systems
# dsl : Domain Specific Language
# dsp : digital signal processing
# dsps : digital signal processors
# dt : Decision Tree
# dtc : direct torque control
# dtd : document type definition
# dtds : document type definition
# dtw : dynamic time warping
# dwt : discrete wavelet transform
# e : ELT
# ea : Evolutionary Algorithms
# ebl : Explanation Based Learning
# ebse : Evidence Based Software Engineering
# ecc : Edge Clustering Coefficient
# ecg : explicitly correlated Gaussian
# ecoc : Error Correcting Output Codes
# eda : estimation distribution algorithm
# edas : Estimation distribution algorithm
# edf : earliest deadline first
# edge : ensemble dependency graph estimator
# eer : equal error rate
# ehrs : Electronic Health Record
# ekf : Extended Kalman Filter
# elm : Extreme Learning Machine
# em : expectation maximization
# emd : empirical mode decomposition
# ep : expectation propagation
# eps : Ensemble Projection
# erp : event related potential
# esa : excited state absorption
# esn : Echo State Networks
# esns : Echo State Network
# f : ferromagneticantiferromagnetic
# facs : Facial Action Coding System
# far : False Acceptance Rate
# fc : functional connectivity
# fca : Formal Concept Analysis
# fcbf : Fast Correlation Based Filter
# fcm : Fuzzy C Means
# fcms : Fuzzy C Means
# fcns : fully convolutional networks
# fds : functional dependencies
# ffbp : Feed Forward Back Propagation
# fft : Fast Fourier Transform
# fis : Fuzzy Inference Systems
# flc : Fuzzy Logic Controller
# flcs : Fuzzy Logic Controller
# fm : Factorization Machine
# fnn : Feedforward Neural Network
# fpga : Field programmable gate array
# fr : face recognition
# frp : Functional reactive programming
# frr : false rejection rate
# fsms : finite state machine
# ga : genetic algorithm
# gar : Genuine Acceptance Rate
# gcc : GNU C Compiler
# gdm : Group Decision Making
# ge : grammatical evolution
# get : generalized evidence theory
# gf : Grammatical Framework
# ghc : Glasgow Haskell Compiler
# gi : Geographic Information
# gmm : Gaussian Mixture Models
# gmms : Gaussian mixture model
# go : Gene Ontology
# gp : Generic programming
# gps : Gaussian Process
# gpu : graphics processing unit
# gpus : Graphics Processing Unit
# gra : grey relational analysis
# grid : Gamma Ray Imaging Detector
# grnn : Generative Regression Neural Network
# gsa : Ground State Alignment
# gsp : Generalized Second Price
# gui : graphical user interface
# h : H
# hci : Human Computer Interaction
# hdfs : Hadoop Distributed File System
# hdl : hardware description language
# hga : hybrid genetic algorithm
# hmd : head mounted display
# hmm : hidden Markov models
# hmms : hidden Markov model
# hog : Histogram oriented Gradient
# hri : Human Robot Interaction
# hsp : Hybrid Stochastic Planning
# html : Hyper Text Markup Language
# hvs : Human Visual System
# ic : interaural coherence
# ica : Independent Component Analysis
# id : Intrusion Detection
# ide : Integrated Development Environments
# idf : inverse document frequency
# ie : information extraction
# ifc : Industrial Foundation Classes
# ig : Information Gain
# iga : Interactive Genetic Algorithm
# ilc : Iterative Learning Control
# ilp : Inductive Logic Programming
# imf : intrinsic mode functions
# imu : Inertial Measurement Unit
# ip : integer programming
# irt : Item response theory
# jml : Java Modeling Language
# kb : knowledge base
# kdd : Knowledge Discovering Databases
# kelm : Kernel Extreme Learning Machine
# km : Knowledge Management
# knn : K Nearest Neighbors
# kpca : kernel principal component analysis
# kqml : Knowledge Query Manipulation Language
# kr : Knowledge Representation
# lbp : local binary patterns
# lcd : liquid crystal display
# lda : linear discriminant analysis
# lds : Linear Dynamical System
# ldss : Linear Dynamical System
# lem : Log Euclidean metric
# lf : logical framework
# lgp : Linear Genetic Programming
# lle : Linear Locally Embedding
# llvm : Low Level Virtual Machine
# lm : language model
# lmi : Linear Matrix Inequality
# lmis : Linear Matrix Inequality
# lof : Local Outlier Factor
# lp : linear programming
# lpc : Linear Predictive Coding
# lpp : Locality preserving projections
# lqr : linear quadratic regulator
# lr : L regularized
# lsa : Latent Semantic Analysis
# lsb : least significant bit
# lsh : locality sensitive hashes
# lsi : Learned Secondary Index
# lstm : long short term memory
# ltag : lexicalized Tree Adjoining Grammar
# ltl : Linear Temporal Logic
# ltm : Long Term Memory
# lts : labeled transition systems
# lvq : Learning Vector Quantization
# mape : Mean Absolute Percentage Error
# mc : Monte Carlo
# mcda : Multiple Criteria Decision Aiding
# mda : Model Driven Architecture
# mdd : model driven development
# mdl : Minimum Description Length
# mdp : Markov decision processes
# mdps : Markov decision process
# mebn : Multi entity Bayesian networks
# mep : Multi Expression Programming
# mfcc : Mel Frequency Cepstral Coefficients
# mhi : Motion History Images
# mkl : multiple kernel learning
# mlc : multi label classifier
# mlp : multi layer perceptron
# mlps : Multi Layer Perceptrons
# mmhc : Max Min Hill Climbing
# mole : Multi Objective Landscape Explorer
# mop : multiobjective optimization problems
# mp : misfolded proteins
# mpc : model predictive control
# mpi : Message Passing Interface
# mr : Mean Recall
# mra : multi resolution analysis
# mrf : Markov Random Field
# mrfs : Markov random fields
# mri : model retraining improvement
# msa : modern standard Arabic
# msc : Message Sequence Charts
# mse : mean standard error
# mso : monadic second order
# mt : Machine translation
# mtf : modulation transfer function
# mtl : multi task learning
# mvp : multi view perceptron
# mwe : Minimum Wasserstein Estimates
# mwes : Minimum Wasserstein Estimates
# n : negative
# nbc : Naive Bayes Classifier
# ne : Named Entity
# ner : named entity recognition
# nfr : Non Functional Requirements
# nlp : Natural Language Processing
# nmf : Nonnegative matrix factorization
# nmfs : negative Matrix Factorization
# nmpc : nonlinear model predictive control
# nmt : neural machine translation
# nn : neural networks
# nns : neural network
# oaa : One against All
# obda : Ontology based data access
# ocl : Object Constraint Language
# ocr : optical character recognition
# olap : On Line Analytical Processing
# omg : Object Management Group
# oop : Object Oriented Programming
# opc : optical proximity correction
# orm : object relational mapping
# osa : obstructive Sleep Apnoea
# owl : Ontology Web Language
# pat : Process Analysis Toolkit
# pbil : Population Based Incremental Learning
# pc : pilot contamination
# pca : principal component analysis
# pd : Parkinsons Disease
# pdc : Parallel Distributed Compensation
# pddl : Planning Domain Description Language
# pdf : Portable Document Format
# pet : Positron emission tomography
# pi : permutation invariance
# pid : proportional integral derivative
# pin : personal identification numbers
# plcs : Programmable Logic Controllers
# pls : passive learning
# pmi : Pointwise Mutual Information
# pmp : Pontryagin maximum principle
# pnn : Probabilistic Neural Network
# pns : Planetary Nebula
# por : partial order reduction
# prf : pseudo relevance feedback
# ps : Pattern search
# psms : Probabilistic Software Modeling
# psnr : Peak signal noise ratio
# pso : Particle Swarm Optimization
# puf : physically unclonable function
# pvs : Prototype Verification System
# qa : question answering
# qap : Quadratic Assignment Problem
# qbf : quantified Boolean formulas
# qbfs : Quantified Boolean Formulas
# qe : quantization error
# qep : query execution plan
# qeps : query execution plan
# qnns : quantum neural network
# qr : Question rewriting
# qsar : Quantitative Structure Activity Relationship
# r : resolution
# ram : random access memory
# rbac : Role Based Access Control
# rbc : ray based classification
# rbf : Radial Basis Function
# rbm : Restricted Boltzmann Machine
# rbms : restricted Boltzmann machine
# rbr : Rule based reasoning
# rdf : Resource Description Framework
# rdfs : Resource Description Framework
# rf : Random Forest
# rfe : Recursive Feature Elimination
# rgb : Red Green Blue
# rmse : root mean squared error
# rnn : recurrent neural network
# rnns : Recurrent Neural Networks
# roc : Receiver Operating Characteristic
# roi : Regions Of Interest
# ror : Robust Ordinal Regression
# rpn : Region Proposal Network
# rsa : Rivest Shamir Adleman
# rst : Rhetorical Structure Theory
# rtos : real time operating System
# rts : real time systems
# rvm : Relevance vector machine
# sat : speaker adaptive training
# sc : solar cycle
# scj : Safety Critical Java
# scm : supply chain management
# sd : soft decision
# sdre : State Dependent Riccati Equation
# se : Software Engineering
# sems : spatial error model
# sfs : stepwise feature selection
# sgd : stochastic gradient descent
# sift : Scale Invariant Feature Transform
# skos : Simple Knowledge Organization System
# slam : Simultaneous Localization and Mapping
# slrs : Systematic Literature Review
# slt : Statistical Learning Theory
# slu : spoken language understanding
# smd : stochastic mirror descent
# smo : Sequential minimal optimization
# smt : statistical machine translation
# smv : Symbolic Model Verifier
# snn : Spiking Neural Network
# soap : Simple Object Access Protocol
# som : Self Organizing Map
# spl : Software Product Line
# spls : Software product lines
# spns : sum product network
# sql : Structured query language
# sr : Sparse Representation
# src : Sparse Representation Classification
# srn : Simultaneous Recurrent Network
# ssa : static single assignment
# ssc : semi supervised clustering
# sse : sea state estimation
# ssl : successive subspace learning
# st : Slavnov Taylor
# stc : Semantic Taxonomical Clustering
# stdp : Spike Timing Dependent Plasticity
# stlf : short term load forecasting
# stm : Support Tensor Machine
# surf : Speeded Up Robust Features
# svc : Signature Verification Competition
# svd : singular value decomposition
# svdd : Support Vector Data Description
# svm : support vector machines
# svms : support vector machines
# svr : Support Vector Regression
# svs : structured variable selection
# swrl : Semantic Web Rule Language
# tag : Tree Adjoining Grammar
# tctl : Timed Computation Tree Logic
# td : temporal differencing
# tfs : term frequency
# tlp : thread level parallelism
# tmis : telecare medical information systems
# tpm : trusted platform module
# tso : Total Store Order
# tsp : Traveling Salesman Problem
# tsps : Travelling Salesman Problems
# ttp : Traveling Thief Problem
# uav : Unmanned Aerial Vehicle
# uavs : unmanned aerial vehicle
# ubm : universal background model
# udfs : User Defined Functions
# ufo : Unified Foundational Ontology
# ui : User interface
# uml : Unified Modeling Language
# umls : Unified Modeling Language
# url : Uniform Resource Locator
# utp : Unifying Theories Programming
# vcg : Vickrey Clarke Groves
# vhdl : VHSIC Hardware Description Language
# vmd : Visual Molecular Dynamics
# vns : Variable Neighborhood Search
# vo : Virtual Observatory
# vq : vector quantized
# vqa : Visual Question Answering
# vsm : Vector Space Model
# wer : Word Error Rate
# wfst : weighted finite state transducer
# wnn : wavelet neural network
# wsd : word sense disambiguation
# wsi : Word Sense Induction
# wt : which two
# www : World Wide Web
# xsds : XML Schema Definition
# xsg : Xilinx System Generator

# %%
# save the dictionary to a file (numpy)
np.save('/tempo/processed-files/definitions.npy', definitions)

# %%
print(f"% of acronyms with definitions: {len(definitions)}/{len(acronyms)} = {round(len(definitions) / len(acronyms) * 100,2)}%")
# Out:
# % of acronyms with definitions: 399/698 = 57.16%

# %%
# count the number of pairs in the df, where at least one of the words has a definition
count = 0
total = 0
for i in range(len(df)):
    if (df['Word A'][i] in acronyms) | (df['Word B'][i] in acronyms):
        total += 1
    if (df['Word A'][i] in definitions) | (df['Word B'][i] in definitions):
        count += 1

print(f"Acronyms with a definition / Total acronyms: \t {count}/{total} = {round(count / total * 100,2)}%")
print(f"Total acronyms / Total pairs: \t\t\t {total}/{len(df)} = {round(total / len(df) * 100,2)}%")
print(f"Acronyms with a definition / Total pairs: \t {count}/{len(df)} = {round(count / len(df) * 100,2)}%")
# Out:
# Acronyms with a definition / Total acronyms: 	 173912/235460 = 73.86%
# Total acronyms / Total pairs: 			 235460/1440317 = 16.35%
# Acronyms with a definition / Total pairs: 	 173912/1440317 = 12.07%
